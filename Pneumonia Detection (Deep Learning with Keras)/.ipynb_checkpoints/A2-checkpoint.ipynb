# %% [markdown]
# # Assignment 3 - Machine Learning Assessment
#
# ## Question 2
#
# ### (a)
# RSS
#
# ### (b)
# $\hat{y} = \frac{74+23+61+74+25+61+54+42+55+75+13+73}{12} = 52.5$
#
# $RSS = \Sigma^n_{i=1} (y_i-\hat{y})^2 = \Sigma^{12}_{i=1} (y_i-52.5)^2$
#
# $=  (74-52.5)^2+(23-52.5)^2+(61-52.5)^2+(74-52.5)^2+(25-52.5)^2+(61-52.5)^2$
#    $+(54-52.5)^2+(42-52.5)^2+(55-52.5)^2+(75-52.5)^2+(13-52.5)^2+(73-52.5)^2 $
# $= 5301$
#
# ### (c)
# The "Labs" variable would be used for the first split.
#
# ### (d)
# $RSS_{post}  = \Sigma_{i\in R_1} (y_i-\hat{y_{R1}})^2 + \Sigma_{i\in R_2} (y_i-\hat{y_{R2}})^2$
#
# $\hat{y_{R1}} = \frac{55+54+73+75+61+74+61+74}{8} = 68.875$
#
# $ \Sigma_{i\in R_1} (y_i-\hat{y_{R1}})^2 = (55-68.875)^2+(54-68.875)^2+(73-68.875)^2$
#  $+(75-68.875)^2+(61-68.875)^2+(74-68.875)^2+(61-68.875)^2+(74-68.875)^2 $
#  $ = 644.875$
#
# $\hat{y_{R2}} = \frac{13+42+25+23}{4} = 25.75$
#
# $ \Sigma_{i\in R_2} (y_i-\hat{y_{R2}})^2 = (13-25.75)^2+(42-25.75)^2+(25-25.75)^2+(23-25.75)^2 $
#  $ = 434.75$
#
# $RSS_{post} = 1079.625$
#
# $ Reduction In RSS= 5301 - 1079.625 = 4221.375$
#
# ### (e)
# $RSS_{post2}  = \Sigma_{i\in R_1} (y_i-\hat{y_{R1}})^2 + \Sigma_{i\in R_2} (y_i-\hat{y_{R2}})^2 + \Sigma_{i\in R_3} (y_i-\hat{y_{R3}})^2$
#
# $\hat{y_{R1}} = \frac {55+54}{2} = 54.5$
#
# $ \Sigma_{i\in R_1} (y_i-\hat{y_{R1}})^2 = (55-54.5)^2 + (54-54.5)^2 = 0.5$
#
# $\hat{y_{R2}} = \frac{73+75+61+74+61+74}{6} = 69.667$
#
# $ \Sigma_{i\in R_2} (y_i-\hat{y_{R2}})^2 = (73-69.667)^2+(75-69.667)^2+(61-69.667)^2+(74-69.667)^2+(61-69.667)^2+(74-69.667)^2$
#  $ = 227.333$
#
# $\hat{y_{R3}} = \frac{13+42+25+23}{4} = 25.75 $
#
# $ \Sigma_{i\in R_3} (y_i-\hat{y_{R3}})^2=(13-25.75)^2+(42-25.75)^2+(25-25.75)^2+(23-25.75)^2$
#  $ = 434.75$
#
# $RSS_{post2}  = 0.5+227.333+434.75 = 662.583$
#
# ### (f)
# predicted score$= 69.667$
#
# ### (g)
# predicted score$= 25.75$
#
# ### (h)
# This could mean there aren't enough observations in the root node for a split to occur. Alternatively,
# they may have used a non-binary splitting procedure to split the tree such as the chi-squared automatic interaction detection (CHAID) method.
#
# ## Question 3
#
# ### (a)
# According to the data, There are three factors which are shown to affect the wine quality. Namely, alcohol, sulphates and acidity.
#
# Alcohol: Denoted by a solid black line in figure 2, shows the greatest potential reduction in RSS at its peak value of 11 as denoted by figure 2.
#
# Sulphates: Denoted by a strong broken line in figure 2, shows the second strongest potential reduction in RSS at its peak value of ~1 by a small margin when compared to acidity.
#
# Acidity: Denoted by a weak dotted line in figure two, shows the weakest potential reduction in RSS at its peak value of ~1 by a small margin when compared to sulphates
#
# Combining these 3 factors to get a quality score for wine using the tree in figure shows we have 8 terminal nodes to predict our outcomes.
# The following combinations will lead to the specified outcomes:
# - 1: alcohol $<$ 11, sulphates $<$ 0.58 $\implies$ Wine Quality = 5.2
# - 2: alcohol $<$ 11, sulphates $>=$ 0.58, acidity $>=$ 0.41 $\implies$ Wine Quality = 5.4
# - 3: alcohol $<$ 11, sulphates $>=$ 0.58, acidity $<$ 0.41 $\implies$ Wine Quality = 5.8
# - 4: alcohol $>$ 11, sulphates $<$ 0.65, acidity $>=$ 1 $\implies$ Wine Quality = 4
# - 5: alcohol $>$ 11, sulphates $<$ 0.65, 0.5 $<=$ acidity $<$ 1 $\implies$ Wine Quality = 5.6
# - 6: alcohol $>$ 11, sulphates $<$ 0.65, acidity $<$ 0.5 $\implies$ Wine Quality = 6.1
# - 7: 11 $<$ alcohol $<=$ 12, sulphate $>$ 0.65 $\implies$ Wine Quality = 6.1
# - 8: alcohol $>$ 12, sulphate $>$ 0.65 $\implies$ Wine Quality = 6.7
#
# ### (b)
# Based on the regression tree in figure three, I'd suggest a rule as follows to ensure a higher chance of a favourable wine quality:
# - alcohol $>$ 12
# - sulphate $>$ 0.65
#
# ### (c)
# The code is written to predict the mean the mean response as predicted by the decision tree model with the following parameters:
# - acidity = 0.2
# - sulphates = 0.6
# - alcohol = 11.5
#
# Based on our decision tree model plotted in figure 3, output would correspond to a mean Wine Quality = 6.1
#
# ### (d)
# Figure 2 plots the potential Reduction in RSS for each of the three factors (alcohol, sulphates and acidity) in our model. The y-axis represents the potential Reduction in RSS for a given factor.
# The x-axis represents the values that the factors are split at to achieve the specific Reduction in RSS. The greater the reduction for any given factor, the
# better for the purposes of improving our model. We choose the factor with the highest peak reduction in RSS for the first split (more generally, for each split).
#
# Explanation and interpretation of the of the specific lines on the figure:
# - Alcohol: Denoted by a solid black line in figure 2, shows the greatest potential reduction in RSS at its peak split value of ~11 as denoted by figure 2.
# - Sulphates: Denoted by a strong broken line in figure 2, shows the second strongest potential reduction in RSS at its peak split value of ~1 by a small margin when compared to acidity.
# - Acidity: Denoted by a weak dotted line in figure 2, shows the weakest potential reduction in RSS at its peak split value of ~1 by a small margin when compared to sulphates
# - Threshold: Denoted by the solid grey line in figure 2, The threshold value in the decision tree model acts as a measure to prevent overfitting by restricting tree depth when the reduction in RSS
# (benefit from a split) becomes too low. The constant threshold value of ~15 means that if no factor can provide a reduction of RSS greater than 15 then we cannot split the tree.
# In this instance it does not affect our decision as every factor can provide a greater reduction in RSS than 15.
# - Based on this figure, it is clear that Alcohol is the correct choice for the first split.
#
# ## Question 4
#
# ### (a)
# - Line 1: The code is reading in the "CTG.csv" csv file into a variable called "data" using a ";" delimiter and "," as the decimal point
# - Line 2: Transforms the NSP (response variable) column into 3 columns to allow binary responses representing each of
# the possible responses for the NSP variable, namely, "Normal", "Suspect" and "Pathologic".
# - Line 3: Sets a Random Seed to ensure a replicable result on any system.
# - Line 4: Creates a sampling index where 1700 items are chosen from a 1-D vector containing 2126 items without replacement (so that no specific element is sampled more than once).
# This is done to prepare for an 80:20 training:test split for our dataset
# - Line 5: Creates a 1700 item random sample of the CTG dataset for training data and stores it in the "train" variable
# - Line 6: Creates a 436 item random sample of the CTG dataset for validation data and stores it in the "validate" variable.
#
# ### (b)
# #### (i)
# ### (c)
# The decision rule based on figure 5 that would indicate a pathological case with the highest degree of confidence would be:
# - MSTV < 0.55
# - ALTV < 69
# - ASTV > 80
#
# ## Question 5
# ### (a)
# The banks needs a large enough dataset of clean data that can be used to train, validate and test the model
#
# ### (b)
# Cost Function: Cross-entropy error
#
# Activation function on output layer: Sigmoid
#
# ### (c)
# The Neural Network has 10 input nodes, 8 nodes in the first hidden layer, 8 nodes in the second hidden layer an 1 output node.
#
# Number of parameters = 10x8 + 8x8 + 8x1 = 152
#
# ## Question 6
# ### (a)
#
# ### (b)
# $a^1_1 = \sigma(5*0.9 + 0.4)=max(0,4.9)=4.9$
#
# $a^1_2 = \sigma(5*0.7 + 0.8)=max(0,4.3)=4.3$
#
# $a^1_3 = \sigma(5*(-0.9) - 0.2)=max(0,-4.7)=0$
#
# $a^1_4 = \sigma(5*(-0.5) - 1.5)=max(0,-4.5)=0$
#
# ### (c)
# $a^2_1 = \sigma(4.9*0.3 + 4.3*0.5 - 0.8) = \sigma(2.82) = 2.82 $
#
# $SSE = \Sigma^N_{i=1}(f_{NN}(x_i,\theta) - y_i)^2 = (2.82-5)^2 = 4.752$

# %%
#Tut
print((55-35.333333)**2+(54-35.333333)**2+(13-35.333333)**2+(42-35.333333)**2+(25-35.333333)**2+(23-35.333333)**2 
      + (73-69.66666667)**2+(75-69.66666667)**2+(61-69.66666667)**2+(74-69.66666667)**2+(61-69.66666667)**2+(74-69.66666667)**2)
#Lab
print((55-68.875)**2+(54-68.875)**2+(73-68.875)**2+(75-68.875)**2+(61-68.875)**2+(74-68.875)**2+(61-68.875)**2+(74-68.875)**2
      +(13-25.75)**2+(42-25.75)**2+(25-25.75)**2+(23-25.75)**2)
#R2
print((73-69.667)**2+(75-69.667)**2+(61-69.667)**2+(74-69.667)**2+(61-69.667)**2+(74-69.667)**2)
#R3
print()
