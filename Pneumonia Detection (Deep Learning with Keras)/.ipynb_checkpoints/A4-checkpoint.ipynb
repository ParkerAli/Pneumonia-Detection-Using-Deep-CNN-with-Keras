# %% [markdown]
# # Assignment 4 - Bayesian Inference Assessment by Mahmood-Ali Parker (PRKMAH005)
# For reference purposes, I have included an excel appendix at the end of each question. The process involved in
# populating each table is written in blue font in the block alongside each table.
# ## Question 1
# For this question, I will be referring to the Question 1 Appendix where necessary.
# ### (a)
# As per Reference 2, without data, the optimal action is to
# drill for oil as the expected return less costs (in millions) $= 0.2*(-10) + 0.5*5 + 0.3*15 = 5$
#
# ### (b)
# As per reference 2, the return using perfect information (in millions) $= 0.2*0 + 0.5*15 + 0.3*25 = 7$
#
# EVPI (Millions) = 7-5 = 2
# ### (c)
# As per the Joint Probabilities Table (Reference 6), the joint probability that the site is dry and the seismic data indicates $x_2$ is
# 0.0534.
#
# ### (d)
# As per the Predictive Probabilities (Reference 7), the probability that the seismic scan detects incomplete rock formations is
# 0.3198
#
# ### (e)
# The posterior predictive probabilities refer to Reference 7.
#
# The prior probability for $\theta_1=0.2$. The posterior probability is 0.287. This means the probability that the site
# is dry has increased.
#
# The prior probability for $\theta_2=0.5$. The posterior probability is 0.32.This means the probability that the site
# is wet has decreased.
#
# The prior probability for $\theta_3=0.3$. The posterior probability is 0.393. This means the probability that the site
# is gushing has increased.
# ### (f)
# (see reference 9)
# ### (g)
# 5.365 Million (as per reference 11)
#
# ### (h)
# The EVSI (Millions) = 5.365-5 = 0.365. This is less than the cost of the seismic scans of R500 000. The oil company
# shouldn't purchase the seismic scan.
#
# ## Question 2
# For this question, I will be referring to the Question 2 section of the appendix where necessary.
# ### (a)
# $\pi_0=0.65$
#
# a priori odds ($H_0$ is true)$= \frac{\pi_0}{1-\pi_0}=\frac{0.65}{1-0.65}\approx 1.857 $
#
# p$=$posterior prob($H_0$ is true)$= \frac{\pi(\theta=0.05|x_1,x_2,...,x_n)}{\pi(\theta=0.05|x_1,x_2,...,x_n)+\pi(\theta=0.22|x_1,x_2,...,x_n)}$
#
# $= \frac {{120 \choose 15}*0.05^{15}(1-0.05)^{120-15}*0.65}{{120 \choose 15}*0.05^{15}(1-0.05)^{120-15}*0.65 + {120 \choose 15}*0.22^{15}(1-0.22)^{120-15}*0.35}$
#
# $= 0.2885612233$
#
# posterior odds($H_0$ is true)$=\frac {p}{1-p} \approx 0.406$
#
# ### (b)
# posterior prob($H_A$ is true)$=$1-posterior prob($H_0$ is true)$\approx 0.711$
#
# ### (c)
# #### (i)
# No, I do not think it is sensible to have a higher cost for a type-II error. This is because a type-II error may lead
# to an under-reaction in response to the virus which may be more devastating in the long-term than the cost associated with
# a type-I error.
#
# ### (ii)
# Let $C_I=C$ then $C_{II}=2C$
#
# $C_I \pi(\theta=0.05|x_1,x_2,...,x_n)=C*0.289=0.289C$
# $C_{II} \pi(\theta=0.22|x_1,x_2,...,x_n) = 2C*0.7114 = 1.423C > C_I \pi(\theta=0.05|x_1,x_2,...,x_n)$
#
# Since $C_I \pi(\theta=0.05|x_1,x_2,...,x_n) < C_{II} \pi(\theta=0.22|x_1,x_2,...,x_n)$, the Bayes' optimal decision
# is to reject $H_0$.
#
# ### (d)
# Using the prior information, the optimal decision would be the strict lockdown. The outcome$=-6*0.65-3*0.35=-4.95 \implies 4.95$ million loss.
#
# ### (e)
# #### (i) *************************************************
# $Pr(\theta=0.05|X=1) = 2 \choose 1 0.05^1*0.95^{2-1}=0.095$
#
# $Pr(X=1|\theta=0.05)=\frac {Pr(\theta=0.05|X=1)Pr(X=1)}{Pr(B)} = \frac{0.095*\frac{1}{2}}{0.65} = 0.073$
#
# or just 0.095 (from table)
#
# #### (ii) ********************************************
# $Pr(\theta = 0.05 \cap X=1)= Pr(\theta=0.05|X=1)Pr(X=1) = 0.095*\frac{1}{2} = 0.0475$
#
# or Pr(\X=1|\theta=0.05)Pr(\theta=0.05) = 0.095*0.65 = 0.06175 (again from table)
#
# #### (iii)
# The posterior predictive probabilities refer to Reference 6, specifically the "2" column.
#
# The prior probability for $\theta_1=0.65$. The posterior probability if 2 deaths are observed is 0.088. This means the
# probability that the death rate is 5% has decreased.
#
# The prior probability for $\theta_2=0.35$. The posterior probability if 2 deaths are observed is 0.912. This means the
# probability that the death rate is 22% has increased.
#
# #### (iv)
# (see Reference 7)
#
# #### (v)
# From reference 9, Predictive Expectation = -4.68071
# $EVSI = -4.68071 - (-4.95) \approx 0.269$
#
# ### (f)
# Mean of Beta Distribution $=\frac{a}{a+b}$
#
# Variance of Beta Distribution $=\frac{ab}{(a+b)^2(a+b+1)}$
#
# $\theta = \frac {a}{a+b} = 0.15$
#
# $a=0.15a+0.15b$
#
# $0.85a=0.15b$
#
# $a=\frac{3}{17}b$
#
# range for the interval $ = 0.2-0.1=0.1$
#
# 95% interval encompasses 4 standard deviations so,
#
# $4\sigma = range =0.1$
#
# $\sigma = 0.025$
#
# $\sigma^2=0.000625 = \frac{ab}{(a+b)^2(a+b+1)} = \frac{\frac{3}{17}b*b}{(\frac{3}{17}b+b)^2(\frac{3}{17}b+b+1)}$
#
# $0.000625 = \frac{\frac{3}{17}b^2}{\frac{400}{289}b^2(\frac{20}{17}b+1)}$
#
# $0.000625 = \frac{221}{400(\frac{20}{17}b+1}$
#
# $0.25(\frac{20}{17}b+1)=221$
#
# $\frac{20}{17}b+1=884$
#
# $b = 750.55$
#
# $a=\frac{3}{17}*750.55=132.45$
#
# So the prior distribution for $\theta$ is beta(132.45, 750.55)
#
# ### (g)
# The beta prior is an informative prior whereas the uniform prior is an uninformative prior. An informative prior
# expresses specific, definite information about a variable. An uninformative prior expresses vague or
# general information about a variable.
#
# ### (h)
# n=120, x=120
#
# $a=a_{old}+x=132.45+15=147.45$
#
# $b=b_{old}+n-x=750.55+120-15=855.55$
#
# $\theta_{posterior}$ ~ beta(147.45, 855.55)
#
# ### (i)
# prior mean $= 0.15$
#
# posterior mean $= \frac{147.45}{147.45+855.55} = 0.147$
#
# So we see the mean has decreased slightly from 0.15 to 0.147 as a result of the information in the data.
#
# ## Question 3
# For this question, I will be referring to the Question 3 section of the appendix where necessary.
# ### (a)
# Looking at Reference 3, the best action to take is the Large Office with Expected return (in thousands)
# $=\frac{40+60+100}{3} = 66.667$
#
# ### (b)
# This response refers to References 5-8.
#
# The prior probability for $\lambda_1\approx 0.333$. The posterior probability if 5 widgets are sold is 0.378. This means the
# probability that demand for widgets will be 5 orders has increased.
#
# The prior probability for $\lambda_2\approx 0.333$. The posterior probability if 5 widgets are sold is 0.346. This means the
# probability that demand for widgets will be 6 orders has increased.
#
# The prior probability for $\lambda_3\approx 0.333$. The posterior probability if 5 widgets are sold is 0.275. This means the
# probability that demand for widgets will be 7 orders has decreased.
#
# ### (c)
# It is a conjugate prior distribution with regards to the likelihood for a poisson distribution. This implies it gives
# rise to a posterior distribution having the same parametric form as the prior i.e a gamma distribution as prior. It
# also represents an informative prior distribution in this case.
#
# ### (d)
# $\mu_{prior}=\alpha * \beta=10*0.5=5$
#
# $\sigma^2_{prior}=\alpha * \beta^2=10*0.5^2=2.5$
#
# ### (e)
# n=6 and $\Sigma^6_{i=1}x_i=32$
#
# In this form of the Gamma distribution, $\beta=\frac{1}{\phi}$ where $\phi$ is the total number of months.
#
# So $\phi_{prior}=\frac{1}{0.5}=2$
#
# $\phi_{posterior} = \phi_{prior}+n = 2+6 = 8$
#
# $\beta_{posterior} = \frac{1}{\phi_{posterior}}=\frac{1}{8}=0.125$
#
# $\alpha_{posterior}=\alpha_{prior}+\Sigma^6_{i=1}x_i=10+32=42$
#
# $\lambda$~Gamma(42,0.125)
#
# ### (f)
# $\mu_{posterior}=\alpha * \beta=42*0.125=5.25$
# $\sigma^2_{posterior}=\alpha * \beta^2=42*0.125^2=0.656$
#
# ### (g)
#
#
#
# ## Question 4
# ### (a)
# X~N($\mu$, $0.67$)
#
# $\mu$~N(3.1, $0.36$)
#
# ### (b)
# n=10, m=3.1, $\bar{x}$=3.5
#
# $\tau = \frac{1}{0.67}=\frac{100}{67}$
#
# $\xi = \frac{1}{0.36}=\frac{25}{9}$
#
# $\hat{\mu}=\frac{\xi m+n\tau \bar{x}}{\xi+n\tau} = \frac{\frac{25}{9}*3.1+10*\frac{100}{67}*3.5}{\frac{25}{9}+10*\frac{100}{67}}$ = 3.437
#
# $Var[\mu|x]= \frac{1}{\xi+n\tau} = \frac{1}{\frac{25}{9}+10*\frac{100}{67}} = 0.056$
#
# posterior $\mu$~N(3.437, 0.056)
#
# ### (c)
# weight of prior mean$=\frac{\xi}{\xi+n\tau}=\frac{\frac{25}{9}}{\frac{25}{9}+10*\frac{100}{67}}=0.157$
#
# weight of posterior mean$=\frac{n\tau}{\xi+n\tau} =\frac{10*\frac{100}{67}}{\frac{25}{9}+10*\frac{100}{67}} = 0.843$
#
# ### (d)
#
#
#
# ### (e)
# #### (i)
# I expect the posterior mean to be much closer to the sample mean as the prior distribution will now
# have an extremely small precision relative to the sample distribution's precision.
#
# #### (ii)
# n=10, m=3.1, $\bar{x}$=3.5
#
# $\tau = \frac{100}{67}$
#
# $\xi = \frac{1}{10000}$
#
# $\hat{\mu}=\frac{\xi m+n\tau \bar{x}}{\xi+n\tau} = \frac{\frac{1}{10000}*3.1+10*\frac{100}{67}*3.5}{\frac{1}{10000}+10*\frac{100}{67}} = 3.499997 \approx 3.5$
#
# $Var[\mu|x]= \frac{1}{\xi+n\tau} = \frac{1}{\frac{1}{10000}+10*\frac{100}{67}} = 0.067$
#
# posterior $\mu$~N(3.5, 0.067)
#
# The posterior mean is now $\approx$3.5 which is the same as the sample's mean of 3.5. Compared to the previous
# posterior distribution, the posterior mean has increased and the posterior variance has increase to 0.067. The increases
# in posterior mean and variance are due to the much lower precision in the new prior distribution (compared to the
# previous prior).
#
# ### (f)
# $\mu_0=$3.1, $\mu_A=$3.5, $\pi_0=0.5$
#
# n$=$15, $\bar{x}=$3.4, $\tau=\frac{1}{0.5}=2$
#
# $L(\mu;x_1,x_2,...,x_n)\propto e^{-n\tau (\bar{x}-\mu)^2/2}$
#
# Odds ($H_A$ true)$ = \frac{L(\mu_A;x_1,x_2,...,x_15)}{L(\mu_0;x_1,x_2,...,x_15)}*\frac{1-\pi_0}{\pi_0} = \frac{e^{-15*2 (3.4-3.5)^2/2}}{e^{-15*2 (3.4-3.1)^2/2}}*1=3.32$
