# %% [markdown]
# ## Question 2
# For this question, I will be referring to the Question 2 appendix where necessary.
# ### (a)
# $\pi_0=0.65$
#
# a priori odds ($H_0$ is true)$= \frac{\pi_0}{1-\pi_0}=\frac{0.65}{1-0.65}\approx 1.857 $
#
# p$=$posterior prob($H_0$ is true)$= \frac{\pi(\theta=0.05|x_1,x_2,...,x_n)}{\pi(\theta=0.05|x_1,x_2,...,x_n)+\pi(\theta=0.22|x_1,x_2,...,x_n)}$
#
# $= \frac {{120 \choose 15}*0.05^{15}(1-0.05)^{120-15}*0.65}{{120 \choose 15}*0.05^{15}(1-0.05)^{120-15}*0.65 + {120 \choose 15}*0.22^{15}(1-0.22)^{120-15}*0.35}$
#
# $= 0.2885612233$
#
# posterior odds($H_0$ is true)$=\frac {p}{1-p} \approx 0.406$
#
# ### (b)
# posterior prob($H_A$ is true)$=$1-posterior prob($H_0$ is true)$\approx 0.711$
#
# ### (c)
# #### (i)
# Yes, I think it is sensible to have a higher cost for a type-II error. This is because a type-I error may lead
# to an under-reaction in response to the virus which may be more devastating in the long-term than the cost associated with a type-II error.
#
# #### (ii)
# Let $C_I=C$ then $C_{II}=2C$
#
# $ Likelihood Ratio = \frac{L(\theta=0.22;x_1,x_2,...,x_n)}{L(\theta=0.05;x_1,x_2,...,x_n)}$
#
# $=\frac{{120 \choose 15}*0.22^{15}(1-0.22)^{120-15}}{{120\choose 15}*0.05^{15}(1-0.05)^{120-15}} $
#
# $=4.579$
#
# $\frac{\pi_0}{1-\pi_0}* \frac{C_I}{C_{II}}=\frac{0.65}{0.35}*\frac{1}{2} = 0.929 \leq 4.579$
#
# Since the likelihood ratio $\geq$ 0.929, the Bayes' optimal decision
# is to reject $H_0$.
#
# ### (d)
# Using the prior information, the optimal decision would be the strict lockdown. The outcome$=-6*0.65-3*0.35=-4.95 \implies 4.95$ million loss.
#
# ### (e)
# #### (i)
# 0.095 (value for the $\theta_1$ state for the 1 column from reference 3)
#
# #### (ii)
# Pr(X=1|$\theta$=0.05)Pr($\theta$=0.05) = 0.095*0.65 = 0.062 (value for the $\theta_1$ state for the 1 column from reference 4)
#
# #### (iii)
# The posterior predictive probabilities refer to Reference 6, specifically the 2 column.
#
# The prior probability for $\theta_1=0.65$. The posterior probability if 2 deaths are observed is 0.088. This means the
# probability that the death rate is 5% has decreased significantly from 0.65 to 0.088.
#
# The prior probability for $\theta_2=0.35$. The posterior probability if 2 deaths are observed is 0.912. This means the
# probability that the death rate is 22% has increased significantly from 0.35 to 0.912.
#
# #### (iv)
# See Reference 7, the SL row specifically.
#
# #### (v)
# From reference 9, Predictive Expectation = -4.68071
# $EVSI = -4.68071 - (-4.95) \approx 0.269$
#
# ### (f)
# Mean of Beta Distribution $=\frac{a}{a+b}$
#
# Variance of Beta Distribution $=\frac{ab}{(a+b)^2(a+b+1)}$
#
# $\theta = \frac {a}{a+b} = 0.15$
#
# $a=0.15a+0.15b$
#
# $0.85a=0.15b$
#
# $a=\frac{3}{17}b$
#
# range for the interval $ = 0.2-0.1=0.1$
#
# 95% interval encompasses 4 standard deviations so,
#
# $4\sigma = range =0.1$
#
# $\sigma = 0.025$
#
# $\sigma^2=0.000625 = \frac{ab}{(a+b)^2(a+b+1)} = \frac{\frac{3}{17}b*b}{(\frac{3}{17}b+b)^2(\frac{3}{17}b+b+1)}$
#
# $0.000625 = \frac{\frac{3}{17}b^2}{\frac{400}{289}b^2(\frac{20}{17}b+1)}$
#
# $0.000625*\frac{400}{289}*\frac{17}{3} = \frac{1}{\frac{20}{17}b+1}$
#
# $\frac{1}{204}=\frac{1}{\frac{20}{17}b+1}$
#
# $ \frac{5}{867}b+\frac{1}{204}=1 $
#
# $\frac{5}{867}b=\frac{203}{204}$
#
# $b = 172.55$
#
# $a=\frac{3}{17}*172.55=30.45$
#
# So the prior distribution for $\theta$ is beta(30.45, 172.55)
#
# ### (g)
# The beta prior is an informative prior whereas the uniform prior is an uninformative prior. An informative prior
# expresses specific, definite information about a variable. An uninformative prior expresses vague or
# general information about a variable.
#
# ### (h)
# n=120, x=15
#
# $a=a_{old}+x=30.45+15=45.45$
#
# $b=b_{old}+n-x=172.55+120-15=277.55$
#
# $\theta_{posterior}$ ~ beta(45.45, 277.55)
#
# ### (i)
# prior mean $= 0.15$
#
# posterior mean $= \frac{45.45}{45.45+277.55} = 0.141$
#
# So we see the mean has decreased from 0.15 to 0.141 as a result of the information in the data.
