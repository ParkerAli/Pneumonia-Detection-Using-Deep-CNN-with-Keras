# %% [markdown]
# # Setting Up NN

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from pathlib import Path
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### M1

# %%
model = Sequential()
model.add(Conv2D(32,
                 (3, 3),
                 padding = 'same',
                 activation = 'relu',
                 input_shape=(256, 256,3)))

model.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(512, activation="relu"))

model.add(Dropout(0.50))

model.add(Dense(1, activation="sigmoid"))

model.compile(
    loss='binary_crossentropy',
    optimizer='rmsprop', 
    metrics=['accuracy'] 
)

model.summary()
model.save_weights('model.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 256, 64)      18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 64)      36928
# ...

# %% [markdown]
# ### M2

# %%
model2 = Sequential()
model2.add(Conv2D(32, (3, 3),padding = 'same',activation = 'relu',
                 input_shape=(256, 256,3)))
model2.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model2.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model2.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Dropout(0.25))

model2.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model2.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Flatten())
model2.add(Dense(512, activation="relu"))

model2.add(Dropout(0.50))

model2.add(Dense(1, activation="sigmoid"))

model2.compile(
    loss='binary_crossentropy',
    optimizer='rmsprop', 
    metrics=['accuracy'] 
)

model2.summary()
model2.save_weights('model2.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_6 (Conv2D)            (None, 256, 256, 32)      896
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 256, 256, 64)      18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 64)        36928
# ...

# %% [markdown]
# ### M3

# %%
model3 = Sequential()
model3.add(Conv2D(16, (3, 3),padding = 'same',activation = 'relu',
                 input_shape=(256, 256,3)))
model3.add(Conv2D(16, (3, 3), padding='same', activation='relu'))
model3.add(MaxPooling2D(pool_size=(2,2)))


model3.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model3.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model3.add(MaxPooling2D(pool_size=(2,2)))

model3.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model3.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model3.add(MaxPooling2D(pool_size=(2,2)))

model3.add(Dropout(0.25))

model3.add(Conv2D(128, (3, 3), padding='same', activation="relu"))
model3.add(Conv2D(128, (3, 3), padding='same', activation="relu"))
model3.add(MaxPooling2D(pool_size=(2,2)))

model3.add(Flatten())
model3.add(Dense(512, activation="relu"))

model3.add(Dropout(0.50))

model3.add(Dense(1, activation="sigmoid"))

model3.compile(
    loss='binary_crossentropy',
    optimizer='rmsprop', 
    metrics=['accuracy'] 
)

model3.summary()
model3.save_weights('model3.h5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_14 (Conv2D)           (None, 256, 256, 16)      448
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 256, 256, 16)      2320
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 128, 128, 32)      4640
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 64, 64, 64)        18496
# ...

# %% [markdown]
# ### M4

# %%
model4 = Sequential()
model4.add(Conv2D(16, (3, 3),padding = 'same',activation = 'relu',
                 input_shape=(256, 256,3)))
model4.add(Conv2D(16, (3, 3), padding='same', activation='relu'))
model4.add(MaxPooling2D(pool_size=(2,2)))


model4.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model4.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model4.add(MaxPooling2D(pool_size=(2,2)))

model4.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model4.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2,2)))

model4.add(Dropout(0.15))

model4.add(Conv2D(128, (3, 3), padding='same', activation="relu"))
model4.add(Conv2D(128, (3, 3), padding='same', activation="relu"))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2,2)))

model4.add(Conv2D(256, (3, 3), padding='same', activation="relu"))
model4.add(Conv2D(256, (3, 3), padding='same', activation="relu"))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2,2)))

model4.add(Dropout(0.25))

model4.add(Conv2D(512, (3, 3), padding='same', activation="relu"))
model4.add(Conv2D(512, (3, 3), padding='same', activation="relu"))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2,2)))

model4.add(Flatten())
model4.add(Dense(512, activation="relu"))

model4.add(Dropout(0.50))

model4.add(Dense(1, activation="sigmoid"))

model4.compile(
    loss='binary_crossentropy',
    optimizer='rmsprop', 
    metrics=['accuracy'] 
)

# model4.summary()
model4.save_weights('model4.h5')

# %% [markdown]
# ### M5

# %%
model5 = Sequential()
model5.add(Conv2D(16, (3, 3),padding = 'same',activation = 'relu',
                 input_shape=(256, 256,3)))
model5.add(Conv2D(16, (3, 3), padding='same', activation='relu'))
model5.add(MaxPooling2D(pool_size=(2,2)))


model5.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model5.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model5.add(Conv2D(64, (3, 3), padding='same', activation="relu"))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Dropout(0.15))

model5.add(Conv2D(128, (3, 3), padding='same', activation="relu"))
model5.add(Conv2D(128, (3, 3), padding='same', activation="relu"))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

# model5.add(Dropout(0.20))

model5.add(Conv2D(256, (3, 3), padding='same', activation="relu"))
model5.add(Conv2D(256, (3, 3), padding='same', activation="relu"))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Dropout(0.20))

model5.add(Conv2D(512, (3, 3), padding='same', activation="relu"))
model5.add(Conv2D(512, (3, 3), padding='same', activation="relu"))
model5.add(BatchNormalization())
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Flatten())
model5.add(Dense(512, activation="relu"))


model5.add(Dense(128, activation="relu"))

model5.add(Dropout(0.20))

model5.add(Dense(1, activation="sigmoid"))

model5.compile(
    loss='binary_crossentropy',
    optimizer='rmsprop', 
    metrics=['accuracy'] 
)

#model5.summary()
model5.save_weights('model5.h5')

# %% [markdown]
# # Loading Training Data
# - We use keras.preprocessing's ImageDataGenerator to create iterators for our dataset.

# %%
batch_size = 64
# create generator
train_gen = ImageDataGenerator(horizontal_flip=True)
val_gen = ImageDataGenerator(rescale=1. / 255)
test_gen = ImageDataGenerator()
# prepare an iterators for each dataset


train_datagen = train_gen.flow_from_directory('/content/gdrive/My Drive/Colab Notebooks/chest_xray/train/',
                                       target_size=(256, 256),
                                       batch_size= batch_size,
                                       class_mode='binary')
val_datagen = val_gen.flow_from_directory('/content/gdrive/My Drive/Colab Notebooks/chest_xray/val/',
                                     target_size=(256, 256),
                                     batch_size= batch_size,
                                     class_mode='binary')

test_datagen = test_gen.flow_from_directory('/content/gdrive/My Drive/Colab Notebooks/chest_xray/test/',
                                     target_size=(256, 256),
                                     batch_size= batch_size,
                                     class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
epochs = 2
epochs2 = 5
epochs3 = 10
epochs4 = 15
epochs5 = 20

# %% [markdown]
# # Training the Model

# %% [markdown]
# ### Model 1

# %%
model_structure=model.to_json()
f = Path('/content/gdrive/My Drive/model_structure.json')
f.write_text(model_structure)
# Out:
# 5014

# %%
model.load_weights('model.h5')
model.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model.save_weights('/content/gdrive/My Drive/model_weights(M1E2).h5')
# Out:
# Epoch 1/2
# 81/81 [==============================] - 1919s 24s/step - loss: 471.3859 - accuracy: 0.7993 - val_loss: 0.6916 - val_accuracy: 0.5000
# Epoch 2/2
# 81/81 [==============================] - 88s 1s/step - loss: 0.7687 - accuracy: 0.8670 - val_loss: 0.6748 - val_accuracy: 0.4375

# %%
model.load_weights('model.h5')
model.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs2,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model.save_weights('/content/gdrive/My Drive/model_weights(M1E5).h5')
# Out:
# Epoch 1/5
# 81/81 [==============================] - 65s 799ms/step - loss: 31.9559 - accuracy: 0.8276 - val_loss: 0.6321 - val_accuracy: 0.6250
# Epoch 2/5
# 81/81 [==============================] - 64s 791ms/step - loss: 0.6227 - accuracy: 0.8670 - val_loss: 1.1146 - val_accuracy: 0.5000
# Epoch 3/5
# 81/81 [==============================] - 64s 788ms/step - loss: 0.3670 - accuracy: 0.8866 - val_loss: 1.3388 - val_accuracy: 0.5625
# Epoch 4/5
# 81/81 [==============================] - 64s 789ms/step - loss: 0.5453 - accuracy: 0.8954 - val_loss: 0.8587 - val_accuracy: 0.6875
# Epoch 5/5
# 81/81 [==============================] - 63s 783ms/step - loss: 7.9493 - accuracy: 0.8993 - val_loss: 0.6291 - val_accuracy: 0.5000

# %%
model.load_weights('model.h5')
model.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs3,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model.save_weights('/content/gdrive/My Drive/model_weights(M1E10).h5')
# Out:
# Epoch 1/10
# 81/81 [==============================] - 66s 815ms/step - loss: 200.3873 - accuracy: 0.8224 - val_loss: 0.6855 - val_accuracy: 0.5000
# Epoch 2/10
# 81/81 [==============================] - 65s 800ms/step - loss: 34.6082 - accuracy: 0.8550 - val_loss: 0.6800 - val_accuracy: 0.5000
# Epoch 3/10
# 81/81 [==============================] - 64s 791ms/step - loss: 7.0254 - accuracy: 0.8981 - val_loss: 0.6568 - val_accuracy: 0.8125
# Epoch 4/10
# 81/81 [==============================] - 64s 796ms/step - loss: 1.6436 - accuracy: 0.8868 - val_loss: 0.6460 - val_accuracy: 0.5000
# Epoch 5/10
# 81/81 [==============================] - 63s 781ms/step - loss: 5.5619 - accuracy: 0.8898 - val_loss: 0.7117 - val_accuracy: 0.5000
# Epoch 6/10
# 81/81 [==============================] - 64s 789ms/step - loss: 5.5112 - accuracy: 0.8993 - val_loss: 0.7871 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
model.load_weights('model.h5')
model.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs4,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model.save_weights('/content/gdrive/My Drive/model_weights(M1E15).h5')
# Out:
# Epoch 1/15
# 81/81 [==============================] - 66s 810ms/step - loss: 55.7682 - accuracy: 0.8050 - val_loss: 0.6818 - val_accuracy: 0.6250
# Epoch 2/15
# 81/81 [==============================] - 63s 780ms/step - loss: 4.8317 - accuracy: 0.8582 - val_loss: 0.6508 - val_accuracy: 0.6875
# Epoch 3/15
# 81/81 [==============================] - 64s 788ms/step - loss: 5.2996 - accuracy: 0.8700 - val_loss: 0.6471 - val_accuracy: 0.6875
# Epoch 4/15
# 81/81 [==============================] - 64s 794ms/step - loss: 1.9422 - accuracy: 0.8958 - val_loss: 1.8165 - val_accuracy: 0.5000
# Epoch 5/15
# 81/81 [==============================] - 64s 793ms/step - loss: 57.7464 - accuracy: 0.8879 - val_loss: 2.3033 - val_accuracy: 0.5000
# Epoch 6/15
# 81/81 [==============================] - 63s 780ms/step - loss: 0.5732 - accuracy: 0.9076 - val_loss: 0.7729 - val_accuracy: 0.5000
# Epoch 7/15
# ...

# %%
model.load_weights('model.h5')
model.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs5,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model.save_weights('/content/gdrive/My Drive/model_weights(M1E20).h5')
# Out:
# Epoch 1/20
# 81/81 [==============================] - 65s 805ms/step - loss: 338.7158 - accuracy: 0.7968 - val_loss: 0.6791 - val_accuracy: 0.6250
# Epoch 2/20
# 81/81 [==============================] - 64s 788ms/step - loss: 6.7950 - accuracy: 0.8610 - val_loss: 0.6532 - val_accuracy: 0.5625
# Epoch 3/20
# 81/81 [==============================] - 64s 785ms/step - loss: 2.0750 - accuracy: 0.8767 - val_loss: 0.6142 - val_accuracy: 0.6875
# Epoch 4/20
# 81/81 [==============================] - 64s 787ms/step - loss: 3.9456 - accuracy: 0.8575 - val_loss: 1.0211 - val_accuracy: 0.5000
# Epoch 5/20
# 81/81 [==============================] - 64s 789ms/step - loss: 5.3264 - accuracy: 0.8944 - val_loss: 1.9071 - val_accuracy: 0.5000
# Epoch 6/20
# 81/81 [==============================] - 64s 791ms/step - loss: 3.0981 - accuracy: 0.8898 - val_loss: 1.6132 - val_accuracy: 0.5000
# Epoch 7/20
# ...

# %% [markdown]
# ### Model 2

# %%
model_structure2=model2.to_json()
f = Path('/content/gdrive/My Drive/model_structure2.json')
f.write_text(model_structure2)
# Out:
# 7246

# %%
model2.load_weights('model2.h5')
model2.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model2.save_weights('/content/gdrive/My Drive/model_weights(M2E2).h5')
# Out:
# Epoch 1/2
# 81/81 [==============================] - 61s 752ms/step - loss: 5.5333 - accuracy: 0.7706 - val_loss: 0.6921 - val_accuracy: 0.5000
# Epoch 2/2
# 81/81 [==============================] - 61s 753ms/step - loss: 0.2930 - accuracy: 0.8806 - val_loss: 0.6952 - val_accuracy: 0.5000

# %%
model2.load_weights('model2.h5')
model2.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs2,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model2.save_weights('/content/gdrive/My Drive/model_weights(M2E5).h5')
# Out:
# Epoch 1/5
# 81/81 [==============================] - 60s 742ms/step - loss: 9.9996 - accuracy: 0.7743 - val_loss: 0.6923 - val_accuracy: 0.5000
# Epoch 2/5
# 81/81 [==============================] - 61s 755ms/step - loss: 0.4337 - accuracy: 0.8492 - val_loss: 0.6971 - val_accuracy: 0.5000
# Epoch 3/5
# 81/81 [==============================] - 62s 762ms/step - loss: 0.3189 - accuracy: 0.8678 - val_loss: 0.7382 - val_accuracy: 0.5000
# Epoch 4/5
# 81/81 [==============================] - 60s 739ms/step - loss: 0.1970 - accuracy: 0.9245 - val_loss: 1.0131 - val_accuracy: 0.5000
# Epoch 5/5
# 81/81 [==============================] - 60s 746ms/step - loss: 0.1482 - accuracy: 0.9464 - val_loss: 1.5550 - val_accuracy: 0.5000

# %%
model2.load_weights('model2.h5')
model2.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs3,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model2.save_weights('/content/gdrive/My Drive/model_weights(M2E10).h5')
# Out:
# Epoch 1/10
# 81/81 [==============================] - 61s 751ms/step - loss: 4.1333 - accuracy: 0.7840 - val_loss: 0.6916 - val_accuracy: 0.5000
# Epoch 2/10
# 81/81 [==============================] - 61s 754ms/step - loss: 0.3382 - accuracy: 0.8544 - val_loss: 0.6904 - val_accuracy: 0.5000
# Epoch 3/10
# 81/81 [==============================] - 62s 761ms/step - loss: 0.2506 - accuracy: 0.9053 - val_loss: 0.7200 - val_accuracy: 0.5000
# Epoch 4/10
# 81/81 [==============================] - 61s 753ms/step - loss: 0.2046 - accuracy: 0.9237 - val_loss: 0.7392 - val_accuracy: 0.5000
# Epoch 5/10
# 81/81 [==============================] - 61s 747ms/step - loss: 0.1378 - accuracy: 0.9524 - val_loss: 0.9505 - val_accuracy: 0.5000
# Epoch 6/10
# 81/81 [==============================] - 61s 756ms/step - loss: 0.1266 - accuracy: 0.9528 - val_loss: 0.8548 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
model2.load_weights('model2.h5')
model2.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs4,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model2.save_weights('/content/gdrive/My Drive/model_weights(M2E15).h5')
# Out:
# Epoch 1/15
# 81/81 [==============================] - 60s 746ms/step - loss: 9.8474 - accuracy: 0.7618 - val_loss: 0.6927 - val_accuracy: 0.5000
# Epoch 2/15
# 81/81 [==============================] - 61s 747ms/step - loss: 0.5408 - accuracy: 0.8488 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 3/15
# 81/81 [==============================] - 60s 744ms/step - loss: 0.2564 - accuracy: 0.9008 - val_loss: 0.6990 - val_accuracy: 0.5000
# Epoch 4/15
# 81/81 [==============================] - 60s 741ms/step - loss: 0.2149 - accuracy: 0.9197 - val_loss: 0.7060 - val_accuracy: 0.5000
# Epoch 5/15
# 81/81 [==============================] - 61s 753ms/step - loss: 0.1488 - accuracy: 0.9468 - val_loss: 0.7299 - val_accuracy: 0.5000
# Epoch 6/15
# 81/81 [==============================] - 60s 744ms/step - loss: 0.1248 - accuracy: 0.9534 - val_loss: 0.8209 - val_accuracy: 0.5000
# Epoch 7/15
# ...

# %%
model2.load_weights('model2.h5')
model2.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs5,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model2.save_weights('/content/gdrive/My Drive/model_weights(M2E20).h5')
# Out:
# Epoch 1/20
# 81/81 [==============================] - 59s 726ms/step - loss: 8.3231 - accuracy: 0.7554 - val_loss: 0.6927 - val_accuracy: 0.5000
# Epoch 2/20
# 81/81 [==============================] - 60s 742ms/step - loss: 0.4847 - accuracy: 0.8507 - val_loss: 0.6867 - val_accuracy: 0.5000
# Epoch 3/20
# 81/81 [==============================] - 59s 728ms/step - loss: 0.2862 - accuracy: 0.8800 - val_loss: 0.7251 - val_accuracy: 0.5000
# Epoch 4/20
# 81/81 [==============================] - 59s 729ms/step - loss: 0.2111 - accuracy: 0.9284 - val_loss: 1.3161 - val_accuracy: 0.5000
# Epoch 5/20
# 81/81 [==============================] - 60s 745ms/step - loss: 0.1664 - accuracy: 0.9377 - val_loss: 0.8929 - val_accuracy: 0.5000
# Epoch 6/20
# 81/81 [==============================] - 61s 747ms/step - loss: 0.1249 - accuracy: 0.9534 - val_loss: 1.5833 - val_accuracy: 0.5000
# Epoch 7/20
# ...

# %% [markdown]
# ### Model 3

# %%
model_structure3=model3.to_json()
f = Path('/content/gdrive/My Drive/model_structure3.json')
f.write_text(model_structure3)
# Out:
# 7253

# %%
model3.load_weights('model3.h5')
model3.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model3.save_weights('/content/gdrive/My Drive/model_weights(M3E2).h5')
# Out:
# Epoch 1/2
# 81/81 [==============================] - 58s 714ms/step - loss: 10.7704 - accuracy: 0.7822 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 2/2
# 81/81 [==============================] - 57s 706ms/step - loss: 0.3887 - accuracy: 0.8449 - val_loss: 0.6927 - val_accuracy: 0.5000

# %%
model3.load_weights('model3.h5')
model3.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs2,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model3.save_weights('/content/gdrive/My Drive/model_weights(M3E5).h5')
# Out:
# Epoch 1/5
# 81/81 [==============================] - 59s 730ms/step - loss: 29.2552 - accuracy: 0.7787 - val_loss: 0.6888 - val_accuracy: 0.5000
# Epoch 2/5
# 81/81 [==============================] - 57s 709ms/step - loss: 0.5527 - accuracy: 0.8606 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 3/5
# 81/81 [==============================] - 57s 708ms/step - loss: 0.2214 - accuracy: 0.9179 - val_loss: 0.9291 - val_accuracy: 0.5000
# Epoch 4/5
# 81/81 [==============================] - 58s 712ms/step - loss: 0.2411 - accuracy: 0.9338 - val_loss: 1.1547 - val_accuracy: 0.5000
# Epoch 5/5
# 81/81 [==============================] - 59s 728ms/step - loss: 0.1319 - accuracy: 0.9526 - val_loss: 2.0855 - val_accuracy: 0.5000

# %%
model3.load_weights('model3.h5')
model3.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs3,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model3.save_weights('/content/gdrive/My Drive/model_weights(M3E10).h5')
# Out:
# Epoch 1/10
# 81/81 [==============================] - 59s 731ms/step - loss: 16.0641 - accuracy: 0.7898 - val_loss: 0.6895 - val_accuracy: 0.5000
# Epoch 2/10
# 81/81 [==============================] - 59s 732ms/step - loss: 0.3816 - accuracy: 0.8525 - val_loss: 0.6899 - val_accuracy: 0.5000
# Epoch 3/10
# 81/81 [==============================] - 59s 729ms/step - loss: 0.3814 - accuracy: 0.8847 - val_loss: 0.7573 - val_accuracy: 0.5000
# Epoch 4/10
# 81/81 [==============================] - 59s 733ms/step - loss: 0.2160 - accuracy: 0.9194 - val_loss: 1.2825 - val_accuracy: 0.5000
# Epoch 5/10
# 81/81 [==============================] - 59s 730ms/step - loss: 0.1693 - accuracy: 0.9387 - val_loss: 2.9561 - val_accuracy: 0.5000
# Epoch 6/10
# 81/81 [==============================] - 60s 735ms/step - loss: 0.1662 - accuracy: 0.9510 - val_loss: 2.3352 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
model3.load_weights('model3.h5')
model3.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs4,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model3.save_weights('/content/gdrive/My Drive/model_weights(M3E15).h5')
# Out:
# Epoch 1/15
# 81/81 [==============================] - 59s 731ms/step - loss: 14.2682 - accuracy: 0.7787 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 2/15
# 81/81 [==============================] - 59s 725ms/step - loss: 0.4256 - accuracy: 0.8313 - val_loss: 0.7148 - val_accuracy: 0.5000
# Epoch 3/15
# 81/81 [==============================] - 59s 725ms/step - loss: 0.3377 - accuracy: 0.8981 - val_loss: 1.1278 - val_accuracy: 0.5000
# Epoch 4/15
# 81/81 [==============================] - 60s 735ms/step - loss: 0.2222 - accuracy: 0.9251 - val_loss: 2.3391 - val_accuracy: 0.5000
# Epoch 5/15
# 81/81 [==============================] - 59s 722ms/step - loss: 0.1567 - accuracy: 0.9400 - val_loss: 1.5511 - val_accuracy: 0.5000
# Epoch 6/15
# 81/81 [==============================] - 59s 732ms/step - loss: 0.1141 - accuracy: 0.9596 - val_loss: 2.5559 - val_accuracy: 0.5000
# Epoch 7/15
# ...

# %%
model3.load_weights('model3.h5')
model3.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs5,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model3.save_weights('/content/gdrive/My Drive/model_weights(M3E20).h5')
# Out:
# Epoch 1/20
# 81/81 [==============================] - 60s 743ms/step - loss: 23.2819 - accuracy: 0.7857 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 2/20
# 81/81 [==============================] - 60s 740ms/step - loss: 0.3363 - accuracy: 0.8597 - val_loss: 0.7214 - val_accuracy: 0.5000
# Epoch 3/20
# 81/81 [==============================] - 60s 737ms/step - loss: 0.3177 - accuracy: 0.9097 - val_loss: 1.2219 - val_accuracy: 0.5000
# Epoch 4/20
# 81/81 [==============================] - 60s 739ms/step - loss: 0.1713 - accuracy: 0.9356 - val_loss: 0.7256 - val_accuracy: 0.5000
# Epoch 5/20
# 81/81 [==============================] - 60s 746ms/step - loss: 0.1855 - accuracy: 0.9412 - val_loss: 1.7150 - val_accuracy: 0.5000
# Epoch 6/20
# 81/81 [==============================] - 59s 723ms/step - loss: 0.1373 - accuracy: 0.9564 - val_loss: 1.3234 - val_accuracy: 0.5000
# Epoch 7/20
# ...

# %% [markdown]
# ### Model 4

# %%
model_structure4=model4.to_json()
f = Path('/content/gdrive/My Drive/model_structure4.json')
f.write_text(model_structure4)
# Out:
# 12508

# %%
# model4.load_weights('model4.h5')
model4.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model4.save_weights('/content/gdrive/My Drive/model_weights(M4E2-2).h5') 
model4.evaluate_generator(test_datagen)
# Out:
# Epoch 1/2
# 81/81 [==============================] - 61s 758ms/step - loss: 1.5040 - accuracy: 0.8075 - val_loss: 10.4737 - val_accuracy: 0.5000
# Epoch 2/2
# 81/81 [==============================] - 60s 745ms/step - loss: 0.3490 - accuracy: 0.8845 - val_loss: 6.1363 - val_accuracy: 0.5000
# [0.7993952631950378, 0.7964743375778198]

# %%
# model4.load_weights('model4.h5')
model4.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=4,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model4.save_weights('/content/gdrive/My Drive/model_weights(M4E4).h5') 
model4.evaluate_generator(test_datagen)
# Out:
# Epoch 1/4
# 81/81 [==============================] - 62s 763ms/step - loss: 1.4649 - accuracy: 0.7892 - val_loss: 2.2992 - val_accuracy: 0.5000
# Epoch 2/4
# 81/81 [==============================] - 61s 754ms/step - loss: 0.4255 - accuracy: 0.8773 - val_loss: 1.0854 - val_accuracy: 0.5000
# Epoch 3/4
# 81/81 [==============================] - 61s 756ms/step - loss: 0.3257 - accuracy: 0.9319 - val_loss: 3.0544 - val_accuracy: 0.5000
# Epoch 4/4
# 81/81 [==============================] - 61s 755ms/step - loss: 0.1850 - accuracy: 0.9482 - val_loss: 1.3145 - val_accuracy: 0.5000
# [0.7671913504600525, 0.692307710647583]

# %%
# model4.load_weights('model4.h5')
model4.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs2,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model4.save_weights('/content/gdrive/My Drive/model_weights(M4E5).h5') 
model4.evaluate_generator(test_datagen)
# Out:
# Epoch 1/5
# 81/81 [==============================] - 61s 758ms/step - loss: 1.4476 - accuracy: 0.7929 - val_loss: 41.9392 - val_accuracy: 0.5000
# Epoch 2/5
# 81/81 [==============================] - 60s 745ms/step - loss: 0.3644 - accuracy: 0.8595 - val_loss: 41.8852 - val_accuracy: 0.5000
# Epoch 3/5
# 81/81 [==============================] - 60s 739ms/step - loss: 0.2776 - accuracy: 0.9026 - val_loss: 54.7351 - val_accuracy: 0.5000
# Epoch 4/5
# 81/81 [==============================] - 60s 742ms/step - loss: 0.1816 - accuracy: 0.9354 - val_loss: 64.3473 - val_accuracy: 0.5000
# Epoch 5/5
# 81/81 [==============================] - 60s 746ms/step - loss: 0.1540 - accuracy: 0.9488 - val_loss: 61.0502 - val_accuracy: 0.5000
# [0.9958090782165527, 0.8141025900840759]

# %%
# model4.load_weights('model4.h5')
model4.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs3,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model4.save_weights('/content/gdrive/My Drive/model_weights(M4E10-2).h5') 
model4.evaluate_generator(test_datagen)
# Out:
# Epoch 1/10
# 81/81 [==============================] - 62s 763ms/step - loss: 1.8292 - accuracy: 0.7615 - val_loss: 6.9747 - val_accuracy: 0.5000
# Epoch 2/10
# 81/81 [==============================] - 61s 749ms/step - loss: 0.3869 - accuracy: 0.8917 - val_loss: 12.7490 - val_accuracy: 0.5000
# Epoch 3/10
# 81/81 [==============================] - 61s 753ms/step - loss: 0.2455 - accuracy: 0.9346 - val_loss: 1.2707 - val_accuracy: 0.5000
# Epoch 4/10
# 81/81 [==============================] - 61s 755ms/step - loss: 0.2039 - accuracy: 0.9424 - val_loss: 1.9255 - val_accuracy: 0.5000
# Epoch 5/10
# 81/81 [==============================] - 62s 761ms/step - loss: 0.1706 - accuracy: 0.9447 - val_loss: 4.4920 - val_accuracy: 0.5000
# Epoch 6/10
# 81/81 [==============================] - 61s 752ms/step - loss: 0.1552 - accuracy: 0.9548 - val_loss: 1.3836 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
# model4.load_weights('model4.h5')
model4.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs4,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model4.save_weights('/content/gdrive/My Drive/model_weights(M4E15-2).h5') 
model4.evaluate_generator(test_datagen)
# Out:
# Epoch 1/15
# 81/81 [==============================] - 60s 743ms/step - loss: 2.0311 - accuracy: 0.7620 - val_loss: 2.1448 - val_accuracy: 0.5000
# Epoch 2/15
# 81/81 [==============================] - 59s 732ms/step - loss: 0.4664 - accuracy: 0.8399 - val_loss: 3.4816 - val_accuracy: 0.5000
# Epoch 3/15
# 81/81 [==============================] - 59s 734ms/step - loss: 0.2710 - accuracy: 0.9125 - val_loss: 4.1191 - val_accuracy: 0.5000
# Epoch 4/15
# 81/81 [==============================] - 59s 728ms/step - loss: 0.2160 - accuracy: 0.9323 - val_loss: 4.8875 - val_accuracy: 0.5000
# Epoch 5/15
# 81/81 [==============================] - 59s 732ms/step - loss: 0.1502 - accuracy: 0.9488 - val_loss: 49.5313 - val_accuracy: 0.5000
# Epoch 6/15
# 81/81 [==============================] - 59s 729ms/step - loss: 0.1436 - accuracy: 0.9546 - val_loss: 3.7386 - val_accuracy: 0.5000
# Epoch 7/15
# ...

# %%
# model4.load_weights('model4.h5')
model4.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs5,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model4.save_weights('/content/gdrive/My Drive/model_weights(M4E20).h5') 
model4.evaluate_generator(test_datagen)
# Out:
# Epoch 1/20
# 81/81 [==============================] - 59s 728ms/step - loss: 1.4666 - accuracy: 0.8075 - val_loss: 12.1614 - val_accuracy: 0.5000
# Epoch 2/20
# 81/81 [==============================] - 58s 721ms/step - loss: 0.3963 - accuracy: 0.8797 - val_loss: 1.5027 - val_accuracy: 0.5000
# Epoch 3/20
# 81/81 [==============================] - 59s 725ms/step - loss: 0.2565 - accuracy: 0.9311 - val_loss: 1.6514 - val_accuracy: 0.5000
# Epoch 4/20
# 81/81 [==============================] - 59s 725ms/step - loss: 0.1611 - accuracy: 0.9507 - val_loss: 2.3323 - val_accuracy: 0.5000
# Epoch 5/20
# 81/81 [==============================] - 59s 734ms/step - loss: 0.2306 - accuracy: 0.9622 - val_loss: 1.0224 - val_accuracy: 0.5000
# Epoch 6/20
# 81/81 [==============================] - 59s 730ms/step - loss: 0.1414 - accuracy: 0.9637 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 7/20
# ...

# %%
#model_structure=model.to_json()
#f = Path('/content/gdrive/My Drive/model_structure3.json')
#f.write_text(model_structure)
#model.save_weights('/content/gdrive/My Drive/model_weights(50E3).h5')

# %% [markdown]
# ### Model 5

# %%
model_structure5=model5.to_json()
f = Path('/content/gdrive/My Drive/model_structure5.json')
f.write_text(model_structure5)
# Out:
# 13537

# %%
#model5.load_weights('model5.h5')
model5.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model5.save_weights('/content/gdrive/My Drive/model_weights(M5E2).h5') 
model5.evaluate_generator(test_datagen)
# Out:
# Epoch 1/2
# 81/81 [==============================] - 60s 745ms/step - loss: 1.1047 - accuracy: 0.7902 - val_loss: 6.1731 - val_accuracy: 0.5000
# Epoch 2/2
# 81/81 [==============================] - 59s 731ms/step - loss: 0.2953 - accuracy: 0.8971 - val_loss: 23.1180 - val_accuracy: 0.5000
# [12.454533576965332, 0.625]

# %%
#model5.load_weights('model5.h5')
model5.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=4,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model5.save_weights('/content/gdrive/My Drive/model_weights(M5E4-2).h5') 
model5.evaluate_generator(test_datagen)
# Out:
# Epoch 1/4
# 81/81 [==============================] - 60s 736ms/step - loss: 0.9086 - accuracy: 0.8141 - val_loss: 18.8686 - val_accuracy: 0.5000
# Epoch 2/4
# 81/81 [==============================] - 59s 726ms/step - loss: 0.2467 - accuracy: 0.9132 - val_loss: 0.6915 - val_accuracy: 0.5000
# Epoch 3/4
# 81/81 [==============================] - 59s 730ms/step - loss: 0.1691 - accuracy: 0.9379 - val_loss: 4.5585 - val_accuracy: 0.5000
# Epoch 4/4
# 81/81 [==============================] - 58s 722ms/step - loss: 0.1474 - accuracy: 0.9523 - val_loss: 29.9062 - val_accuracy: 0.5000
# [29.097885131835938, 0.625]

# %%
#model5.load_weights('model5.h5')
model5.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs2,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model5.save_weights('/content/gdrive/My Drive/model_weights(M5E5-2).h5') 
model5.evaluate_generator(test_datagen)
# Out:
# Epoch 1/5
# 81/81 [==============================] - 60s 740ms/step - loss: 1.1341 - accuracy: 0.8049 - val_loss: 2.1324 - val_accuracy: 0.5000
# Epoch 2/5
# 81/81 [==============================] - 59s 725ms/step - loss: 0.4247 - accuracy: 0.8837 - val_loss: 2.7251 - val_accuracy: 0.5000
# Epoch 3/5
# 81/81 [==============================] - 58s 722ms/step - loss: 0.2395 - accuracy: 0.9321 - val_loss: 4.4978 - val_accuracy: 0.5000
# Epoch 4/5
# 81/81 [==============================] - 59s 726ms/step - loss: 0.1649 - accuracy: 0.9505 - val_loss: 5.9055 - val_accuracy: 0.5000
# Epoch 5/5
# 81/81 [==============================] - 59s 730ms/step - loss: 0.1525 - accuracy: 0.9540 - val_loss: 5.3956 - val_accuracy: 0.5000
# [3.7518842220306396, 0.625]

# %%
#model5.load_weights('model5.h5')
model5.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=6,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model5.save_weights('/content/gdrive/My Drive/model_weights(M5E6).h5') 
model5.evaluate_generator(test_datagen)
# Out:
# Epoch 1/6
# 81/81 [==============================] - 60s 746ms/step - loss: 1.0684 - accuracy: 0.8121 - val_loss: 3.8033 - val_accuracy: 0.5000
# Epoch 2/6
# 81/81 [==============================] - 59s 723ms/step - loss: 0.2264 - accuracy: 0.9200 - val_loss: 1.0785 - val_accuracy: 0.5000
# Epoch 3/6
# 81/81 [==============================] - 59s 733ms/step - loss: 0.1683 - accuracy: 0.9548 - val_loss: 6.2960 - val_accuracy: 0.5000
# Epoch 4/6
# 81/81 [==============================] - 60s 746ms/step - loss: 0.1327 - accuracy: 0.9593 - val_loss: 23.7162 - val_accuracy: 0.5000
# Epoch 5/6
# 81/81 [==============================] - 59s 730ms/step - loss: 0.1130 - accuracy: 0.9613 - val_loss: 26.1071 - val_accuracy: 0.5000
# Epoch 6/6
# 81/81 [==============================] - 60s 741ms/step - loss: 0.1084 - accuracy: 0.9684 - val_loss: 9.6137 - val_accuracy: 0.5000
# [3.124765157699585, 0.6939102411270142]

# %%
#model5.load_weights('model5.h5')
model5.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs3,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model5.save_weights('/content/gdrive/My Drive/model_weights(M5E10).h5') 
model5.evaluate_generator(test_datagen)
# Out:
# Epoch 1/10
# 81/81 [==============================] - 60s 738ms/step - loss: 1.1958 - accuracy: 0.8304 - val_loss: 1.4682 - val_accuracy: 0.5000
# Epoch 2/10
# 81/81 [==============================] - 59s 723ms/step - loss: 0.2695 - accuracy: 0.9080 - val_loss: 4.4338 - val_accuracy: 0.5000
# Epoch 3/10
# 81/81 [==============================] - 59s 727ms/step - loss: 0.1742 - accuracy: 0.9472 - val_loss: 0.9784 - val_accuracy: 0.5000
# Epoch 4/10
# 81/81 [==============================] - 58s 719ms/step - loss: 0.1947 - accuracy: 0.9515 - val_loss: 22.0301 - val_accuracy: 0.5000
# Epoch 5/10
# 81/81 [==============================] - 59s 730ms/step - loss: 0.1123 - accuracy: 0.9626 - val_loss: 0.7337 - val_accuracy: 0.5000
# Epoch 6/10
# 81/81 [==============================] - 59s 724ms/step - loss: 0.1237 - accuracy: 0.9607 - val_loss: 200.7272 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
model5.load_weights('model5.h5')
model5.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs4,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model5.save_weights('/content/gdrive/My Drive/model_weights(M5E15).h5')
# Out:
# Epoch 1/15
# 81/81 [==============================] - 59s 728ms/step - loss: 1.0536 - accuracy: 0.8043 - val_loss: 11.6288 - val_accuracy: 0.5000
# Epoch 2/15
# 81/81 [==============================] - 60s 735ms/step - loss: 0.4694 - accuracy: 0.9030 - val_loss: 2.0970 - val_accuracy: 0.5000
# Epoch 3/15
# 81/81 [==============================] - 59s 730ms/step - loss: 0.3018 - accuracy: 0.9280 - val_loss: 7.4981 - val_accuracy: 0.5000
# Epoch 4/15
# 81/81 [==============================] - 60s 743ms/step - loss: 0.2351 - accuracy: 0.9406 - val_loss: 4.7044 - val_accuracy: 0.5000
# Epoch 5/15
# 81/81 [==============================] - 61s 747ms/step - loss: 0.2361 - accuracy: 0.9581 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 6/15
# 81/81 [==============================] - 61s 751ms/step - loss: 0.2167 - accuracy: 0.9565 - val_loss: 21.9499 - val_accuracy: 0.5000
# Epoch 7/15
# ...

# %%
model5.load_weights('model5.h5')
model5.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=epochs5,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model5.save_weights('/content/gdrive/My Drive/model_weights(M5E20).h5')
# Out:
# Epoch 1/20
# 81/81 [==============================] - 60s 736ms/step - loss: 1.0006 - accuracy: 0.7964 - val_loss: 3.8813 - val_accuracy: 0.5000
# Epoch 2/20
# 81/81 [==============================] - 60s 736ms/step - loss: 0.5051 - accuracy: 0.8670 - val_loss: 2.3535 - val_accuracy: 0.5000
# Epoch 3/20
# 81/81 [==============================] - 60s 737ms/step - loss: 0.3675 - accuracy: 0.9229 - val_loss: 0.7557 - val_accuracy: 0.5000
# Epoch 4/20
# 81/81 [==============================] - 60s 742ms/step - loss: 0.2705 - accuracy: 0.9398 - val_loss: 1.6345 - val_accuracy: 0.5000
# Epoch 5/20
# 81/81 [==============================] - 59s 731ms/step - loss: 0.2708 - accuracy: 0.9515 - val_loss: 1.8892 - val_accuracy: 0.5000
# Epoch 6/20
# 81/81 [==============================] - 59s 728ms/step - loss: 0.1840 - accuracy: 0.9556 - val_loss: 2.2052 - val_accuracy: 0.5000
# Epoch 7/20
# ...

# %%
model5.load_weights('model5.h5')
model5.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=25,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model5.save_weights('/content/gdrive/My Drive/model_weights(M5E25).h5')
# Out:
# Epoch 1/25
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 19 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 22/81 [=======>......................] - ETA: 28:09 - loss: 2.0553 - accuracy: 0.7311
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 3 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 25/81 [========>.....................] - ETA: 26:52 - loss: 1.9961 - accuracy: 0.7328
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 59 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 27/81 [=========>....................] - ETA: 25:57 - loss: 1.8686 - accuracy: 0.7429
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 39 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# ...

# %%
model5.load_weights('model5.h5')
model5.fit_generator(
        train_datagen,
        steps_per_epoch=5216 // batch_size, 
        epochs=30,
        validation_data=val_datagen,
        validation_steps= 16 // batch_size)
model5.save_weights('/content/gdrive/My Drive/model_weights(M5E30).h5')
# Out:
# Epoch 1/30
# 81/81 [==============================] - 68s 837ms/step - loss: 1.5286 - accuracy: 0.7824 - val_loss: 4.3814 - val_accuracy: 0.5000
# Epoch 2/30
# 81/81 [==============================] - 67s 824ms/step - loss: 0.3796 - accuracy: 0.9026 - val_loss: 1.1038 - val_accuracy: 0.5000
# Epoch 3/30
# 81/81 [==============================] - 63s 781ms/step - loss: 0.2834 - accuracy: 0.9284 - val_loss: 3.4772 - val_accuracy: 0.5000
# Epoch 4/30
# 81/81 [==============================] - 63s 778ms/step - loss: 0.2818 - accuracy: 0.9420 - val_loss: 2.2708 - val_accuracy: 0.5000
# Epoch 5/30
# 81/81 [==============================] - 67s 823ms/step - loss: 0.2525 - accuracy: 0.9546 - val_loss: 3.5903 - val_accuracy: 0.5000
# Epoch 6/30
# 81/81 [==============================] - 66s 819ms/step - loss: 0.1500 - accuracy: 0.9569 - val_loss: 2.6429 - val_accuracy: 0.5000
# Epoch 7/30
# ...

# %%
model5.evaluate_generator(test_datagen)
# Out:
# [13.092185020446777, 0.6378205418586731]
